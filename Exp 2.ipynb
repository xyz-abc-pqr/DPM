# %% [markdown]
# ## Experiment No.2

# %% [markdown]
# Importing the required Libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# Getting some random video ID

# %%
video_id="ewvddSUEONQ"

# %% [markdown]
# Visit the above Website https://console.cloud.google.com and create the API from that page. And Paste it over Here

# %%
api_key="AIzaSyC4HfMq77lfRkyzwbvLw5dUoS3UQPfd1hM"

# %% [markdown]
# URL of the Youtube required to hit the request

# %%
url="https://www.googleapis.com/youtube/v3"

# %%
url
# Out:
# 'https://www.googleapis.com/youtube/v3'

# %% [markdown]
# ## Extracting the Details of the Youtube Video ID

# %%
video_url=url+"/videos?id={}&key={}&part=snippet".format(video_id,api_key)
video_url
# Out:
# 'https://www.googleapis.com/youtube/v3/videos?id=ewvddSUEONQ&key=AIzaSyC4HfMq77lfRkyzwbvLw5dUoS3UQPfd1hM&part=snippet'

# %%
data=requests.get(video_url)

# %%
data=data.json()
data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'mv6B40UW6Lyq6HsKUkBRz7Dhedo',
#  'items': [{'kind': 'youtube#video',
#    'etag': '1Py7yRmcWHG2HbLorTy7troLNIY',
#    'id': 'ewvddSUEONQ',
#    'snippet': {'publishedAt': '2021-04-09T08:30:06Z',
#     'channelId': 'UCFFbwnve3yF62-tVXkTyHqg',
#     'title': 'Behti Hawa Sa Tha Woh – 3 Idiots | Aamir Khan, Madhavan, Sharman J | Shaan & Shantanu M | Swanand K',
# ...

# %%
print("Video title = ",data["items"][0]["snippet"]["title"])
print("Channel Name = ",data["items"][0]["snippet"]["channelTitle"])
# Out:
# Video title =  Behti Hawa Sa Tha Woh – 3 Idiots | Aamir Khan, Madhavan, Sharman J | Shaan & Shantanu M | Swanand K
# Channel Name =  Zee Music Company

# %% [markdown]
# ## Extracting the Top Level Comments from the above Video

# %% [markdown]
# Calling the Youtube API to extract the comments

# %%
comment_url=url+"/commentThreads?key={}&part=snippet&videoId={}&maxResults=30".format(api_key,video_id)
comment_url
# Out:
# 'https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyC4HfMq77lfRkyzwbvLw5dUoS3UQPfd1hM&part=snippet&videoId=ewvddSUEONQ&maxResults=30'

# %%
commentData=requests.get(comment_url)
commentData
# Out:
# <Response [200]>

# %%
commentData=commentData.json()
commentData
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'FoS3k-n6GpyH1FbEoH_2c0sUzBk',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpSklCZ0FFZ1VJcUNBWUFCSUZDSWNnR0FBU0JRaWRJQmdCR0FBaURnb01DSXJSbnJFR0VNaTJsdWND',
#  'pageInfo': {'totalResults': 30, 'resultsPerPage': 30},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'n3Oiwc-Dm9IWF1ktRFytgs4io3I',
#    'id': 'UgwZCtOZd9bSJYHOeId4AaABAg',
#    'snippet': {'channelId': 'UCFFbwnve3yF62-tVXkTyHqg',
#     'videoId': 'ewvddSUEONQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Y88laDVqErMu3NzKV2Rh8w5HVs4',
#      'id': 'UgwZCtOZd9bSJYHOeId4AaABAg',
#      'snippet': {'channelId': 'UCFFbwnve3yF62-tVXkTyHqg',
#       'videoId': 'ewvddSUEONQ',
#       'textDisplay': '❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉❤',
#       'textOriginal': '❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉❤',
#       'authorDisplayName': '@hetpatel887',
# ...

# %% [markdown]
# Extracting the Comments

# %%
comments=[item["snippet"]["topLevelComment"]["snippet"]["textOriginal"] for item in commentData["items"]]
comments
# Out:
# ['❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉❤',
#  'All time best song  all year best movie 3 idiot',
#  'Kehte naki, "duniya ka shabkuch time ke shath alag ho jati hai, lekin achsi friendship kabhi bhi nahi alag hoti hai".',
#  'Kon kon 2024 me dakh raha hai',
#  'Who has come here by searching like me in 2024',
#  '25 April 2024',
#  'I think name of this movie shall be 4Idiots😂\nIncluding Chatur',
#  'This movie is really touched every student heart❤',
#  '자네나히~',
#  'I miss myself, happy n healthy version of mine...badly suffering from cancer at the age of 22 ... I miss you buddy you were a great great guy ♥️',
#  'Leh ladakh india is heaven❤',
#  'Miss you2024💔💔💔💔💔😭😭😭😭😭',
#  'Miss you🥺😢💔',
#  'Hum',
#  'Me',
#  '❤😢',
#  '1912',
#  'Heart touching song❤❤',
#  'This movie is touching my heart ❤️❤️',
#  '😢😢😢😢😢😢😢',
#  'My favourite movie is 3 idiots ❤❤😅😊',
#  'N v',
#  'Why did Bollywood stopped making such films',
#  '❤❤️\u200d🩹',
#  'This song is really a masterpiece',
# ...

# %% [markdown]
# Displaying the Comments

# %%
df=pd.DataFrame({"Comments":comments})
df
# Out:
#                                              Comments
# 0                                      ❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉❤
# 1     All time best song  all year best movie 3 idiot
# 2   Kehte naki, "duniya ka shabkuch time ke shath ...
# 3                       Kon kon 2024 me dakh raha hai
# 4      Who has come here by searching like me in 2024
# 5                                       25 April 2024
# 6   I think name of this movie shall be 4Idiots😂\n...
# 7   This movie is really touched every student heart❤
# 8                                               자네나히~
# 9   I miss myself, happy n healthy version of mine...
# 10                        Leh ladakh india is heaven❤
# 11                             Miss you2024💔💔💔💔💔😭😭😭😭😭
# 12                                        Miss you🥺😢💔
# 13                                                Hum
# 14                                                 Me
# 15                                                 ❤😢
# ...
