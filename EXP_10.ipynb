# %%
from textblob import TextBlob

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
data = '/content/sma10 - Sheet1.csv'  # Adjust the path accordingly

# %%
df = pd.read_csv(data)

# %%
import pandas as pd
df1=pd.read_csv('/content/sample_data/speaker spreadsheet - Sheet1.csv')
df1.head()

# %%
summary2=df1['Summary']

# %%
summary_speaker_list=[]
speaker_sentiment_list=[]
sentiment=[]
for summ in summary2:
  sentiment= get_summary_sentiment(summ)
  summary_list.append(summ)
  speaker_sentiment_list.append(sentiment)
  print(f"{summ}:{sentiment}")

# %%
positive1=0
positive2=0
neutral1=0
neutral2=0
negative1=0
negative2=0
for rew in sentiment_list:
  if rew=='positive':
    positive1+=1
  if rew=='netural':
    neutral1+=1
  if rew=='negative':
    negative1+=1
for rew in speaker_sentiment_list:
  if rew=='positive':
    positive2+=1
  if rew=='netural':
    neutral2+=1
  if rew=='negative':
    negative2+=1

# %%
import numpy as np
import matplotlib.pyplot as plt
X = ['Positive','negative','neutral']
p1 = [positive1,negative1,neutral1]
p2 = [positive2,negative2,neutral2]
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, p1, 0.4, label = 'Candes')
plt.bar(X_axis + 0.2, p2, 0.4, label = 'Maharaja')
plt.xticks(X_axis, X)
plt.xlabel("Product")
plt.ylabel("No of review")
plt.title("Product comparision")
plt.legend()
plt.show()

# %%
p1_1=34
p1_2=56
p1_3=51
p1_4=34
p1_5=44
p2_1=34
p2_2=43
p2_3=36
p2_4=47
p2_5=64

# %%
import matplotlib.pyplot as plt

X = ['1','2','3','4','5']
p1 = [p1_1,p1_2,p1_3,p1_4,p1_5]
p2 = [p2_1,p2_2,p2_3,p2_4,p2_5]

fig, ax = plt.subplots()

# Stacked bar chart
ax.bar(X, p1)
ax.bar(X, p2, bottom = p1)

plt.show()
