# %% [markdown]
# # Experiment No. 5

# %% [markdown]
# Importing The Required Libraries

# %%
import pandas as pd
import requests
from textblob import TextBlob

# %% [markdown]
# Getting the Api keys and video id

# %%
video_id="ewvddSUEONQ"
api_key="AIzaSyC4HfMq77lfRkyzwbvLw5dUoS3UQPfd1hM"
url="https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={}&key={}&maxResults=50".format(video_id,api_key)

# %%
url
# Out:
# 'https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ewvddSUEONQ&key=AIzaSyC4HfMq77lfRkyzwbvLw5dUoS3UQPfd1hM&maxResults=50'

# %% [markdown]
# Requesting to get the toplevel Comments

# %%
data=requests.get(url)
data
# Out:
# <Response [200]>

# %%
data=data.json()
data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'l1ORfCsdqrXPfUYYg6nqLk6dQI8',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJa2dHQUFTQlFpSElCZ0FFZ1VJblNBWUFSSUZDSWdnR0FBU0JRaW9JQmdBR0FBaURRb0xDT3Z2ajdFR0VPQ24xVDA=',
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'n3Oiwc-Dm9IWF1ktRFytgs4io3I',
#    'id': 'UgwZCtOZd9bSJYHOeId4AaABAg',
#    'snippet': {'channelId': 'UCFFbwnve3yF62-tVXkTyHqg',
#     'videoId': 'ewvddSUEONQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Y88laDVqErMu3NzKV2Rh8w5HVs4',
#      'id': 'UgwZCtOZd9bSJYHOeId4AaABAg',
#      'snippet': {'channelId': 'UCFFbwnve3yF62-tVXkTyHqg',
#       'videoId': 'ewvddSUEONQ',
#       'textDisplay': '❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉❤',
#       'textOriginal': '❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉❤',
#       'authorDisplayName': '@hetpatel887',
# ...

# %%
comments=[item["snippet"]["topLevelComment"]["snippet"]["textOriginal"] for item in data["items"]]

# %%
comments
# Out:
# ['❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉❤',
#  'All time best song  all year best movie 3 idiot',
#  'Kehte naki, "duniya ka shabkuch time ke shath alag ho jati hai, lekin achsi friendship kabhi bhi nahi alag hoti hai".',
#  'Kon kon 2024 me dakh raha hai',
#  'Who has come here by searching like me in 2024',
#  '25 April 2024',
#  'I think name of this movie shall be 4Idiots😂\nIncluding Chatur',
#  'This movie is really touched every student heart❤',
#  '자네나히~',
#  'I miss myself, happy n healthy version of mine...badly suffering from cancer at the age of 22 ... I miss you buddy you were a great great guy ♥️',
#  'Leh ladakh india is heaven❤',
#  'Miss you2024💔💔💔💔💔😭😭😭😭😭',
#  'Miss you🥺😢💔',
#  'Hum',
#  'Me',
#  '❤😢',
#  '1912',
#  'Heart touching song❤❤',
#  'This movie is touching my heart ❤️❤️',
#  '😢😢😢😢😢😢😢',
#  'My favourite movie is 3 idiots ❤❤😅😊',
#  'N v',
#  'Why did Bollywood stopped making such films',
#  '❤❤️\u200d🩹',
#  'This song is really a masterpiece',
# ...

# %% [markdown]
# ## Sentiment Analysis on Extracted Comments

# %%
def sentiment_analysis(comment:str)-> str:
    analysis=TextBlob(comment)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity ==0:
        return "Neutral"
    return "Negative"

# %%
sentiments=list()
for comment in comments:
    sentiments.append(sentiment_analysis(comment))

# %% [markdown]
# ## Combining the Sentiment and their Comment into a Dataframe

# %%
df=pd.DataFrame({"Comment":comments,"Sentiment":sentiments})
df
# Out:
#                                               Comment Sentiment
# 0                                      ❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉❤   Neutral
# 1     All time best song  all year best movie 3 idiot  Positive
# 2   Kehte naki, "duniya ka shabkuch time ke shath ...   Neutral
# 3                       Kon kon 2024 me dakh raha hai   Neutral
# 4      Who has come here by searching like me in 2024   Neutral
# 5                                       25 April 2024   Neutral
# 6   I think name of this movie shall be 4Idiots😂\n...   Neutral
# 7   This movie is really touched every student heart❤  Positive
# 8                                               자네나히~   Neutral
# 9   I miss myself, happy n healthy version of mine...  Positive
# 10                        Leh ladakh india is heaven❤   Neutral
# 11                             Miss you2024💔💔💔💔💔😭😭😭😭😭   Neutral
# 12                                        Miss you🥺😢💔   Neutral
# 13                                                Hum   Neutral
# ...
